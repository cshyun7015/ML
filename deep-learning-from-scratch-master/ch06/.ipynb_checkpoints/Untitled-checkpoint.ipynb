# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from common.optimizer import *

# %matplotlib inline

def f(x, y):
    return x**2 / 20.0 + y**2


def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0


optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
    

    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y) 
    Z = f(X, Y)
    
    # 외곽선 단순화
    mask = Z > 7
    Z[mask] = 0
    
    # 그래프 그리기
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim(-10, 10)
    plt.plot(0, 0, '+')
    #colorbar()
    #spring()
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.4267395895471244
# Momentum:2.4201074912350196
# AdaGrad:2.310099616238663
# Adam:2.1757577307874305
# ===========iteration:100===========
# SGD:1.2325809518763884
# Momentum:0.24839591625289834
# AdaGrad:0.0862724508804663
# Adam:0.22016849733294377
# ===========iteration:200===========
# SGD:0.7150933792749672
# Momentum:0.24236794184932473
# AdaGrad:0.10045178144593188
# Adam:0.20293786995618923
# ===========iteration:300===========
# SGD:0.4266187726123776
# Momentum:0.14752803874718312
# AdaGrad:0.07282937922605912
# Adam:0.11427394189237972
# ===========iteration:400===========
# SGD:0.4208254342454373
# Momentum:0.20295992383702244
# AdaGrad:0.0773946618779756
# Adam:0.1827204766840207
# ===========iteration:500===========
# SGD:0.3045349575926747
# Momentum:0.17036406833584866
# AdaGrad:0.04472498153548064
# Adam:0.06648635004536094
# ===========iteration:600===========
# SGD:0.3015837175143292
# Momentum:0.10499502421684817
# AdaGrad:0.0444650439382901
# Adam:0.05315769298398121
# ===========iteration:700===========
# SGD:0.36181481759210804
# Momentum:0.10445251167825714
# AdaGrad:0.04687956172841498
# Adam:0.07793397725326212
# ===========iteration:800===========
# SGD:0.31787614699732875
# Momentum:0.1553819984826721
# AdaGrad:0.055676664774469364
# Adam:0.08831584351219786
# ===========iteration:900===========
# SGD:0.32642117062257425
# Momentum:0.1046316071800209
# AdaGrad:0.03680307718805158
# Adam:0.05514346195874383
# ===========iteration:1000===========
# SGD:0.29826803524272244
# Momentum:0.09250583339357342
# AdaGrad:0.03477160984540917
# Adam:0.03860211189886166
# ===========iteration:1100===========
# SGD:0.20743333131780417
# Momentum:0.04234628555756313
# AdaGrad:0.034879026842524266
# Adam:0.06655471238645616
# ===========iteration:1200===========
# SGD:0.1826484510429597
# Momentum:0.051621553457400736
# AdaGrad:0.010201755893202059
# Adam:0.012125814158118654
# ===========iteration:1300===========
# SGD:0.30106338395621335
# Momentum:0.06256640328520305
# AdaGrad:0.04194816968600126
# Adam:0.03230943088093584
# ===========iteration:1400===========
# SGD:0.33365670399926306
# Momentum:0.09322965986723111
# AdaGrad:0.04299021998219409
# Adam:0.05857666121071138
# ===========iteration:1500===========
# SGD:0.27838000782162337
# Momentum:0.10258215854970912
# AdaGrad:0.036853267192202485
# Adam:0.04719618662077876
# ===========iteration:1600===========
# SGD:0.15601535555244211
# Momentum:0.09421035331771167
# AdaGrad:0.030732415788073193
# Adam:0.03723925561161884
# ===========iteration:1700===========
# SGD:0.18570150972917443
# Momentum:0.041488720831187056
# AdaGrad:0.01904634695046225
# Adam:0.017687571321177674
# ===========iteration:1800===========
# SGD:0.21689734901708052
# Momentum:0.08672542795668647
# AdaGrad:0.026442601795784067
# Adam:0.033001890211664574
# ===========iteration:1900===========
# SGD:0.29229092646850174
# Momentum:0.0916161549289694
# AdaGrad:0.037361638025484784
# Adam:0.04202527157339113

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 초깃값을 다양하게 바꿔가며 실험해보자！
    w = np.random.randn(node_num, node_num) * 1
    # w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 활성화 함수도 바꿔가며 실험해보자！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# 히스토그램 그리기
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.30255138928
# Xavier:2.305494778693139
# He:2.319822407553314
# ===========iteration:100===========
# std=0.01:2.3017464808804284
# Xavier:2.2786368930103413
# He:1.6624122226873186
# ===========iteration:200===========
# std=0.01:2.3018095763250748
# Xavier:2.228861633592796
# He:0.6796371535835048
# ===========iteration:300===========
# std=0.01:2.3018431372046666
# Xavier:2.135950763158859
# He:0.451289796790603
# ===========iteration:400===========
# std=0.01:2.3013567335044742
# Xavier:1.8224449880460636
# He:0.42100243142446275
# ===========iteration:500===========
# std=0.01:2.295489400187706
# Xavier:1.3881377102828063
# He:0.32681862860448463
# ===========iteration:600===========
# std=0.01:2.3008801016539078
# Xavier:0.9538537764437078
# He:0.2983917576089452
# ===========iteration:700===========
# std=0.01:2.3013326854758205
# Xavier:0.7205599343945265
# He:0.30788325704176844
# ===========iteration:800===========
# std=0.01:2.299821922324001
# Xavier:0.6621624630684042
# He:0.4153218522324344
# ===========iteration:900===========
# std=0.01:2.2996575213630304
# Xavier:0.4213095057925203
# He:0.19110483666469613
# ===========iteration:1000===========
# std=0.01:2.29901202733525
# Xavier:0.5311983795843673
# He:0.34972211568885847
# ===========iteration:1100===========
# std=0.01:2.2991667240159015
# Xavier:0.4177159232674362
# He:0.2795629748220499
# ===========iteration:1200===========
# std=0.01:2.3065882456306075
# Xavier:0.35734160755949396
# He:0.24282386433216382
# ===========iteration:1300===========
# std=0.01:2.3002820350639315
# Xavier:0.33977537941516006
# He:0.1328526503442018
# ===========iteration:1400===========
# std=0.01:2.2979088327470203
# Xavier:0.4982975822860616
# He:0.3188520185959389
# ===========iteration:1500===========
# std=0.01:2.3042921127645455
# Xavier:0.3214856500430441
# He:0.25471587610206586
# ===========iteration:1600===========
# std=0.01:2.300456283594062
# Xavier:0.21422417214758024
# He:0.14055812940635357
# ===========iteration:1700===========
# std=0.01:2.311578768151257
# Xavier:0.26977905122692164
# He:0.20657434566802882
# ===========iteration:1800===========
# std=0.01:2.307917098696284
# Xavier:0.2957451656051411
# He:0.1908911767399385
# ===========iteration:1900===========
# std=0.01:2.2960186552762694
# Xavier:0.2400988738285367
# He:0.16493673179394439

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 학습 데이터를 줄임
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 그래프 그리기==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.094 - 0.09
# ../common/multi_layer_net_extend.py:104: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../common/multi_layer_net_extend.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:1 | 0.116 - 0.102
# epoch:2 | 0.116 - 0.081
# epoch:3 | 0.116 - 0.107
# epoch:4 | 0.116 - 0.126
# epoch:5 | 0.116 - 0.153
# epoch:6 | 0.116 - 0.188
# epoch:7 | 0.116 - 0.2
# epoch:8 | 0.116 - 0.228
# epoch:9 | 0.116 - 0.251
# epoch:10 | 0.116 - 0.276
# epoch:11 | 0.116 - 0.293
# epoch:12 | 0.116 - 0.315
# epoch:13 | 0.116 - 0.331
# epoch:14 | 0.116 - 0.354
# epoch:15 | 0.116 - 0.362
# epoch:16 | 0.116 - 0.371
# epoch:17 | 0.116 - 0.389
# epoch:18 | 0.116 - 0.4
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.412
# ============== 2/16 ==============
# epoch:0 | 0.096 - 0.106
# ../common/functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# ../common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# epoch:1 | 0.097 - 0.124
# epoch:2 | 0.097 - 0.155
# epoch:3 | 0.097 - 0.175
# epoch:4 | 0.097 - 0.205
# epoch:5 | 0.097 - 0.222
# epoch:6 | 0.097 - 0.246
# epoch:7 | 0.097 - 0.278
# epoch:8 | 0.097 - 0.297
# epoch:9 | 0.097 - 0.318
# epoch:10 | 0.097 - 0.344
# epoch:11 | 0.097 - 0.373
# epoch:12 | 0.097 - 0.383
# epoch:13 | 0.097 - 0.418
# epoch:14 | 0.097 - 0.437
# epoch:15 | 0.097 - 0.461
# epoch:16 | 0.097 - 0.467
# epoch:17 | 0.097 - 0.491
# epoch:18 | 0.097 - 0.496
# No handles with labels found to put in legend.
# epoch:19 | 0.097 - 0.526
# ============== 3/16 ==============
# epoch:0 | 0.113 - 0.1
# epoch:1 | 0.404 - 0.105
# epoch:2 | 0.576 - 0.119
# epoch:3 | 0.662 - 0.146
# epoch:4 | 0.74 - 0.183
# epoch:5 | 0.799 - 0.221
# epoch:6 | 0.82 - 0.26
# epoch:7 | 0.871 - 0.292
# epoch:8 | 0.9 - 0.329
# epoch:9 | 0.912 - 0.363
# epoch:10 | 0.923 - 0.393
# epoch:11 | 0.948 - 0.427
# epoch:12 | 0.957 - 0.464
# epoch:13 | 0.968 - 0.501
# epoch:14 | 0.979 - 0.513
# epoch:15 | 0.982 - 0.53
# epoch:16 | 0.984 - 0.543
# epoch:17 | 0.987 - 0.574
# epoch:18 | 0.989 - 0.589
# No handles with labels found to put in legend.
# epoch:19 | 0.992 - 0.612
# ============== 4/16 ==============
# epoch:0 | 0.114 - 0.088
# epoch:1 | 0.2 - 0.1
# epoch:2 | 0.312 - 0.161
# epoch:3 | 0.403 - 0.26
# epoch:4 | 0.487 - 0.338
# epoch:5 | 0.546 - 0.403
# epoch:6 | 0.582 - 0.478
# epoch:7 | 0.627 - 0.531
# epoch:8 | 0.652 - 0.564
# epoch:9 | 0.683 - 0.6
# epoch:10 | 0.717 - 0.63
# epoch:11 | 0.732 - 0.657
# epoch:12 | 0.752 - 0.685
# epoch:13 | 0.771 - 0.713
# epoch:14 | 0.776 - 0.722
# epoch:15 | 0.788 - 0.746
# epoch:16 | 0.801 - 0.758
# epoch:17 | 0.824 - 0.773
# epoch:18 | 0.826 - 0.781
# No handles with labels found to put in legend.
# epoch:19 | 0.842 - 0.791
# ============== 5/16 ==============
# epoch:0 | 0.147 - 0.076
# epoch:1 | 0.16 - 0.114
# epoch:2 | 0.163 - 0.224
# epoch:3 | 0.182 - 0.374
# epoch:4 | 0.191 - 0.489
# epoch:5 | 0.199 - 0.582
# epoch:6 | 0.202 - 0.638
# epoch:7 | 0.208 - 0.684
# epoch:8 | 0.22 - 0.722
# epoch:9 | 0.221 - 0.734
# epoch:10 | 0.232 - 0.742
# epoch:11 | 0.245 - 0.767
# epoch:12 | 0.249 - 0.779
# epoch:13 | 0.252 - 0.798
# epoch:14 | 0.259 - 0.813
# epoch:15 | 0.262 - 0.829
# epoch:16 | 0.275 - 0.839
# epoch:17 | 0.271 - 0.848
# epoch:18 | 0.273 - 0.853
# No handles with labels found to put in legend.
# epoch:19 | 0.286 - 0.862
# ============== 6/16 ==============
# epoch:0 | 0.131 - 0.124
# epoch:1 | 0.117 - 0.228
# epoch:2 | 0.116 - 0.464
# epoch:3 | 0.116 - 0.618
# epoch:4 | 0.116 - 0.688
# epoch:5 | 0.116 - 0.741
# epoch:6 | 0.116 - 0.768
# epoch:7 | 0.11 - 0.796
# epoch:8 | 0.113 - 0.818
# epoch:9 | 0.103 - 0.836
# epoch:10 | 0.116 - 0.858
# epoch:11 | 0.116 - 0.87
# epoch:12 | 0.116 - 0.878
# epoch:13 | 0.116 - 0.892
# epoch:14 | 0.116 - 0.898
# epoch:15 | 0.116 - 0.903
# epoch:16 | 0.116 - 0.912
# epoch:17 | 0.112 - 0.919
# epoch:18 | 0.12 - 0.929
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.933
# ============== 7/16 ==============
# epoch:0 | 0.099 - 0.145
# epoch:1 | 0.116 - 0.367
# epoch:2 | 0.116 - 0.629
# epoch:3 | 0.116 - 0.726
# epoch:4 | 0.116 - 0.78
# epoch:5 | 0.116 - 0.823
# epoch:6 | 0.116 - 0.853
# epoch:7 | 0.116 - 0.885
# epoch:8 | 0.116 - 0.902
# epoch:9 | 0.116 - 0.917
# epoch:10 | 0.116 - 0.93
# epoch:11 | 0.116 - 0.944
# epoch:12 | 0.116 - 0.95
# epoch:13 | 0.116 - 0.96
# epoch:14 | 0.116 - 0.968
# epoch:15 | 0.116 - 0.975
# epoch:16 | 0.116 - 0.985
# epoch:17 | 0.116 - 0.99
# epoch:18 | 0.116 - 0.996
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.995
# ============== 8/16 ==============
# epoch:0 | 0.107 - 0.101
# epoch:1 | 0.105 - 0.351
# epoch:2 | 0.116 - 0.634
# epoch:3 | 0.116 - 0.748
# epoch:4 | 0.116 - 0.792
# epoch:5 | 0.116 - 0.864
# epoch:6 | 0.117 - 0.916
# epoch:7 | 0.116 - 0.944
# epoch:8 | 0.117 - 0.962
# epoch:9 | 0.117 - 0.976
# epoch:10 | 0.117 - 0.975
# epoch:11 | 0.117 - 0.984
# epoch:12 | 0.117 - 0.99
# epoch:13 | 0.117 - 0.994
# epoch:14 | 0.117 - 0.995
# epoch:15 | 0.117 - 0.996
# epoch:16 | 0.117 - 0.999
# epoch:17 | 0.116 - 0.997
# epoch:18 | 0.116 - 0.998
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.999
# ============== 9/16 ==============
# epoch:0 | 0.097 - 0.125
# epoch:1 | 0.116 - 0.555
# epoch:2 | 0.116 - 0.704
# epoch:3 | 0.116 - 0.803
# epoch:4 | 0.116 - 0.857
# epoch:5 | 0.116 - 0.887
# epoch:6 | 0.117 - 0.941
# epoch:7 | 0.116 - 0.962
# epoch:8 | 0.117 - 0.977
# epoch:9 | 0.116 - 0.986
# epoch:10 | 0.117 - 0.996
# epoch:11 | 0.117 - 0.998
# epoch:12 | 0.117 - 0.999
# epoch:13 | 0.117 - 0.999
# epoch:14 | 0.117 - 0.999
# epoch:15 | 0.117 - 1.0
# epoch:16 | 0.117 - 1.0
# epoch:17 | 0.117 - 1.0
# epoch:18 | 0.117 - 1.0
# epoch:19 | 0.117 - 1.0
# No handles with labels found to put in legend.
# ============== 10/16 ==============
# epoch:0 | 0.105 - 0.121
# epoch:1 | 0.116 - 0.55
# epoch:2 | 0.116 - 0.742
# epoch:3 | 0.116 - 0.748
# epoch:4 | 0.117 - 0.778
# epoch:5 | 0.117 - 0.844
# epoch:6 | 0.117 - 0.865
# epoch:7 | 0.117 - 0.86
# epoch:8 | 0.117 - 0.875
# epoch:9 | 0.117 - 0.904
# epoch:10 | 0.117 - 0.97
# epoch:11 | 0.117 - 0.991
# epoch:12 | 0.117 - 0.993
# epoch:13 | 0.117 - 0.995
# epoch:14 | 0.117 - 0.995
# epoch:15 | 0.117 - 0.997
# epoch:16 | 0.117 - 0.962
# epoch:17 | 0.117 - 0.991
# epoch:18 | 0.116 - 0.994
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.997
# ============== 11/16 ==============
# epoch:0 | 0.105 - 0.166
# epoch:1 | 0.117 - 0.679
# epoch:2 | 0.117 - 0.722
# epoch:3 | 0.117 - 0.547
# epoch:4 | 0.116 - 0.777
# epoch:5 | 0.116 - 0.843
# epoch:6 | 0.116 - 0.869
# epoch:7 | 0.116 - 0.859
# epoch:8 | 0.116 - 0.747
# epoch:9 | 0.116 - 0.952
# epoch:10 | 0.116 - 0.964
# epoch:11 | 0.117 - 0.949
# epoch:12 | 0.117 - 0.982
# epoch:13 | 0.116 - 0.99
# epoch:14 | 0.116 - 0.991
# epoch:15 | 0.116 - 0.992
# epoch:16 | 0.116 - 0.987
# epoch:17 | 0.116 - 0.992
# epoch:18 | 0.116 - 0.994
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.992
# ============== 12/16 ==============
# epoch:0 | 0.116 - 0.127
# epoch:1 | 0.116 - 0.359
# epoch:2 | 0.116 - 0.589
# epoch:3 | 0.116 - 0.618
# epoch:4 | 0.116 - 0.623
# epoch:5 | 0.116 - 0.677
# epoch:6 | 0.117 - 0.616
# epoch:7 | 0.117 - 0.658
# epoch:8 | 0.117 - 0.688
# epoch:9 | 0.117 - 0.699
# epoch:10 | 0.117 - 0.692
# epoch:11 | 0.117 - 0.701
# epoch:12 | 0.117 - 0.687
# epoch:13 | 0.117 - 0.698
# epoch:14 | 0.117 - 0.693
# epoch:15 | 0.117 - 0.709
# epoch:16 | 0.117 - 0.706
# epoch:17 | 0.116 - 0.714
# epoch:18 | 0.116 - 0.709
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.714
# ============== 13/16 ==============
# epoch:0 | 0.099 - 0.18
# epoch:1 | 0.116 - 0.552
# epoch:2 | 0.116 - 0.704
# epoch:3 | 0.116 - 0.727
# epoch:4 | 0.116 - 0.76
# epoch:5 | 0.116 - 0.784
# epoch:6 | 0.116 - 0.753
# epoch:7 | 0.116 - 0.798
# epoch:8 | 0.116 - 0.816
# epoch:9 | 0.116 - 0.84
# epoch:10 | 0.116 - 0.803
# epoch:11 | 0.116 - 0.781
# epoch:12 | 0.116 - 0.788
# epoch:13 | 0.116 - 0.807
# epoch:14 | 0.117 - 0.798
# epoch:15 | 0.117 - 0.802
# epoch:16 | 0.117 - 0.882
# epoch:17 | 0.117 - 0.893
# epoch:18 | 0.117 - 0.983
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.965
# ============== 14/16 ==============
# epoch:0 | 0.099 - 0.106
# epoch:1 | 0.1 - 0.334
# epoch:2 | 0.117 - 0.424
# epoch:3 | 0.117 - 0.424
# epoch:4 | 0.117 - 0.472
# epoch:5 | 0.117 - 0.439
# epoch:6 | 0.117 - 0.467
# epoch:7 | 0.117 - 0.452
# epoch:8 | 0.117 - 0.504
# epoch:9 | 0.117 - 0.499
# epoch:10 | 0.117 - 0.507
# epoch:11 | 0.117 - 0.511
# epoch:12 | 0.117 - 0.51
# epoch:13 | 0.117 - 0.518
# epoch:14 | 0.117 - 0.513
# epoch:15 | 0.117 - 0.526
# epoch:16 | 0.116 - 0.514
# epoch:17 | 0.116 - 0.515
# epoch:18 | 0.116 - 0.513
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.529
# ============== 15/16 ==============
# epoch:0 | 0.105 - 0.189
# epoch:1 | 0.116 - 0.214
# epoch:2 | 0.116 - 0.394
# epoch:3 | 0.116 - 0.406
# epoch:4 | 0.116 - 0.42
# epoch:5 | 0.116 - 0.409
# epoch:6 | 0.116 - 0.426
# epoch:7 | 0.116 - 0.432
# epoch:8 | 0.116 - 0.429
# epoch:9 | 0.116 - 0.424
# epoch:10 | 0.116 - 0.431
# epoch:11 | 0.116 - 0.43
# epoch:12 | 0.116 - 0.51
# epoch:13 | 0.116 - 0.52
# epoch:14 | 0.116 - 0.58
# epoch:15 | 0.116 - 0.611
# epoch:16 | 0.116 - 0.578
# epoch:17 | 0.116 - 0.606
# epoch:18 | 0.116 - 0.621
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.622
# ============== 16/16 ==============
# epoch:0 | 0.116 - 0.114
# epoch:1 | 0.116 - 0.208
# epoch:2 | 0.116 - 0.265
# epoch:3 | 0.117 - 0.323
# epoch:4 | 0.117 - 0.323
# epoch:5 | 0.117 - 0.323
# epoch:6 | 0.117 - 0.325
# epoch:7 | 0.117 - 0.418
# epoch:8 | 0.117 - 0.427
# epoch:9 | 0.117 - 0.43
# epoch:10 | 0.117 - 0.427
# epoch:11 | 0.117 - 0.429
# epoch:12 | 0.117 - 0.43
# epoch:13 | 0.116 - 0.43
# epoch:14 | 0.116 - 0.429
# epoch:15 | 0.116 - 0.432
# epoch:16 | 0.116 - 0.432
# epoch:17 | 0.116 - 0.427
# epoch:18 | 0.117 - 0.431
# epoch:19 | 0.117 - 0.431

# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.09666666666666666, test acc:0.0728
# epoch:1, train acc:0.11666666666666667, test acc:0.0922
# epoch:2, train acc:0.15666666666666668, test acc:0.1153
# epoch:3, train acc:0.16666666666666666, test acc:0.1302
# epoch:4, train acc:0.19333333333333333, test acc:0.1493
# epoch:5, train acc:0.21666666666666667, test acc:0.1665
# epoch:6, train acc:0.23333333333333334, test acc:0.1842
# epoch:7, train acc:0.26, test acc:0.1958
# epoch:8, train acc:0.2733333333333333, test acc:0.205
# epoch:9, train acc:0.29, test acc:0.219
# epoch:10, train acc:0.29333333333333333, test acc:0.2318
# epoch:11, train acc:0.32, test acc:0.241
# epoch:12, train acc:0.34, test acc:0.254
# epoch:13, train acc:0.35333333333333333, test acc:0.265
# epoch:14, train acc:0.38, test acc:0.2789
# epoch:15, train acc:0.41, test acc:0.2866
# epoch:16, train acc:0.41333333333333333, test acc:0.292
# epoch:17, train acc:0.4266666666666667, test acc:0.3081
# epoch:18, train acc:0.43, test acc:0.3046
# epoch:19, train acc:0.44666666666666666, test acc:0.3142
# epoch:20, train acc:0.45666666666666667, test acc:0.3245
# epoch:21, train acc:0.46, test acc:0.3266
# epoch:22, train acc:0.4633333333333333, test acc:0.3348
# epoch:23, train acc:0.45666666666666667, test acc:0.3372
# epoch:24, train acc:0.4633333333333333, test acc:0.3384
# epoch:25, train acc:0.47333333333333333, test acc:0.3427
# epoch:26, train acc:0.4766666666666667, test acc:0.3442
# epoch:27, train acc:0.4766666666666667, test acc:0.3556
# epoch:28, train acc:0.48, test acc:0.3638
# epoch:29, train acc:0.4866666666666667, test acc:0.3702
# epoch:30, train acc:0.4866666666666667, test acc:0.3672
# epoch:31, train acc:0.49333333333333335, test acc:0.3728
# epoch:32, train acc:0.5, test acc:0.3845
# epoch:33, train acc:0.5133333333333333, test acc:0.3931
# epoch:34, train acc:0.5266666666666666, test acc:0.4046
# epoch:35, train acc:0.53, test acc:0.4068
# epoch:36, train acc:0.5466666666666666, test acc:0.4088
# epoch:37, train acc:0.54, test acc:0.4033
# epoch:38, train acc:0.5566666666666666, test acc:0.4172
# epoch:39, train acc:0.5566666666666666, test acc:0.4159
# epoch:40, train acc:0.5833333333333334, test acc:0.4341
# epoch:41, train acc:0.6033333333333334, test acc:0.4493
# epoch:42, train acc:0.5966666666666667, test acc:0.4472
# epoch:43, train acc:0.59, test acc:0.4576
# epoch:44, train acc:0.5833333333333334, test acc:0.458
# epoch:45, train acc:0.5966666666666667, test acc:0.4696
# epoch:46, train acc:0.6, test acc:0.4692
# epoch:47, train acc:0.6133333333333333, test acc:0.4737
# epoch:48, train acc:0.6333333333333333, test acc:0.4908
# epoch:49, train acc:0.6466666666666666, test acc:0.4936
# epoch:50, train acc:0.6433333333333333, test acc:0.4963
# epoch:51, train acc:0.64, test acc:0.4997
# epoch:52, train acc:0.64, test acc:0.5037
# epoch:53, train acc:0.6566666666666666, test acc:0.5132
# epoch:54, train acc:0.6566666666666666, test acc:0.5194
# epoch:55, train acc:0.6733333333333333, test acc:0.5287
# epoch:56, train acc:0.69, test acc:0.5418
# epoch:57, train acc:0.6866666666666666, test acc:0.5435
# epoch:58, train acc:0.7133333333333334, test acc:0.5581
# epoch:59, train acc:0.71, test acc:0.5591
# epoch:60, train acc:0.7133333333333334, test acc:0.5617
# epoch:61, train acc:0.73, test acc:0.5677
# epoch:62, train acc:0.7233333333333334, test acc:0.5663
# epoch:63, train acc:0.7366666666666667, test acc:0.5773
# epoch:64, train acc:0.7366666666666667, test acc:0.5965
# epoch:65, train acc:0.7566666666666667, test acc:0.6001
# epoch:66, train acc:0.7666666666666667, test acc:0.6096
# epoch:67, train acc:0.7733333333333333, test acc:0.6029
# epoch:68, train acc:0.7566666666666667, test acc:0.6031
# epoch:69, train acc:0.7566666666666667, test acc:0.6034
# epoch:70, train acc:0.7633333333333333, test acc:0.6099
# epoch:71, train acc:0.7666666666666667, test acc:0.6165
# epoch:72, train acc:0.78, test acc:0.6105
# epoch:73, train acc:0.78, test acc:0.6237
# epoch:74, train acc:0.8, test acc:0.6299
# epoch:75, train acc:0.8, test acc:0.6363
# epoch:76, train acc:0.7966666666666666, test acc:0.6279
# epoch:77, train acc:0.82, test acc:0.6415
# epoch:78, train acc:0.8166666666666667, test acc:0.6368
# epoch:79, train acc:0.8233333333333334, test acc:0.6383
# epoch:80, train acc:0.82, test acc:0.6504
# epoch:81, train acc:0.8233333333333334, test acc:0.6583
# epoch:82, train acc:0.8266666666666667, test acc:0.655
# epoch:83, train acc:0.8366666666666667, test acc:0.6523
# epoch:84, train acc:0.83, test acc:0.6548
# epoch:85, train acc:0.82, test acc:0.6431
# epoch:86, train acc:0.8333333333333334, test acc:0.6541
# epoch:87, train acc:0.83, test acc:0.6381
# epoch:88, train acc:0.8433333333333334, test acc:0.6607
# epoch:89, train acc:0.83, test acc:0.6516
# epoch:90, train acc:0.8433333333333334, test acc:0.6629
# epoch:91, train acc:0.8466666666666667, test acc:0.67
# epoch:92, train acc:0.8366666666666667, test acc:0.6649
# epoch:93, train acc:0.85, test acc:0.6702
# epoch:94, train acc:0.8533333333333334, test acc:0.6712
# epoch:95, train acc:0.84, test acc:0.663
# epoch:96, train acc:0.85, test acc:0.6741
# epoch:97, train acc:0.87, test acc:0.6816
# epoch:98, train acc:0.8566666666666667, test acc:0.6815
# epoch:99, train acc:0.8466666666666667, test acc:0.6716
# epoch:100, train acc:0.8433333333333334, test acc:0.6694
# epoch:101, train acc:0.8533333333333334, test acc:0.6748
# epoch:102, train acc:0.8533333333333334, test acc:0.683
# epoch:103, train acc:0.85, test acc:0.6704
# epoch:104, train acc:0.8766666666666667, test acc:0.693
# epoch:105, train acc:0.87, test acc:0.6916
# epoch:106, train acc:0.8666666666666667, test acc:0.6892
# epoch:107, train acc:0.8733333333333333, test acc:0.6926
# epoch:108, train acc:0.8866666666666667, test acc:0.6907
# epoch:109, train acc:0.87, test acc:0.6917
# epoch:110, train acc:0.8766666666666667, test acc:0.6941
# epoch:111, train acc:0.89, test acc:0.6887
# epoch:112, train acc:0.87, test acc:0.6915
# epoch:113, train acc:0.87, test acc:0.6918
# epoch:114, train acc:0.8633333333333333, test acc:0.696
# epoch:115, train acc:0.87, test acc:0.6945
# epoch:116, train acc:0.87, test acc:0.7011
# epoch:117, train acc:0.8633333333333333, test acc:0.6938
# epoch:118, train acc:0.8766666666666667, test acc:0.7065
# epoch:119, train acc:0.8766666666666667, test acc:0.702
# epoch:120, train acc:0.8833333333333333, test acc:0.7021
# epoch:121, train acc:0.8866666666666667, test acc:0.6996
# epoch:122, train acc:0.88, test acc:0.7064
# epoch:123, train acc:0.8933333333333333, test acc:0.6905
# epoch:124, train acc:0.8966666666666666, test acc:0.7067
# epoch:125, train acc:0.8933333333333333, test acc:0.7059
# epoch:126, train acc:0.89, test acc:0.7045
# epoch:127, train acc:0.86, test acc:0.6956
# epoch:128, train acc:0.8766666666666667, test acc:0.7012
# epoch:129, train acc:0.8733333333333333, test acc:0.7008
# epoch:130, train acc:0.8833333333333333, test acc:0.707
# epoch:131, train acc:0.8766666666666667, test acc:0.7107
# epoch:132, train acc:0.8833333333333333, test acc:0.7099
# epoch:133, train acc:0.88, test acc:0.6994
# epoch:134, train acc:0.88, test acc:0.7016
# epoch:135, train acc:0.88, test acc:0.7058
# epoch:136, train acc:0.8666666666666667, test acc:0.6966
# epoch:137, train acc:0.8766666666666667, test acc:0.7056
# epoch:138, train acc:0.8766666666666667, test acc:0.7058
# epoch:139, train acc:0.8866666666666667, test acc:0.7046
# epoch:140, train acc:0.8833333333333333, test acc:0.7067
# epoch:141, train acc:0.8866666666666667, test acc:0.711
# epoch:142, train acc:0.89, test acc:0.7072
# epoch:143, train acc:0.8966666666666666, test acc:0.7079
# epoch:144, train acc:0.8866666666666667, test acc:0.7076
# epoch:145, train acc:0.8866666666666667, test acc:0.7069
# epoch:146, train acc:0.8933333333333333, test acc:0.7065
# epoch:147, train acc:0.89, test acc:0.7103
# epoch:148, train acc:0.8933333333333333, test acc:0.7108
# epoch:149, train acc:0.9, test acc:0.7119
# epoch:150, train acc:0.8766666666666667, test acc:0.7011
# epoch:151, train acc:0.8833333333333333, test acc:0.7047
# epoch:152, train acc:0.8933333333333333, test acc:0.7085
# epoch:153, train acc:0.8933333333333333, test acc:0.7083
# epoch:154, train acc:0.8733333333333333, test acc:0.7141
# epoch:155, train acc:0.8833333333333333, test acc:0.7116
# epoch:156, train acc:0.8833333333333333, test acc:0.7127
# epoch:157, train acc:0.88, test acc:0.706
# epoch:158, train acc:0.88, test acc:0.7033
# epoch:159, train acc:0.9, test acc:0.7164
# epoch:160, train acc:0.8733333333333333, test acc:0.7171
# epoch:161, train acc:0.89, test acc:0.723
# epoch:162, train acc:0.8933333333333333, test acc:0.7187
# epoch:163, train acc:0.8933333333333333, test acc:0.7187
# epoch:164, train acc:0.8866666666666667, test acc:0.7128
# epoch:165, train acc:0.8933333333333333, test acc:0.7133
# epoch:166, train acc:0.8866666666666667, test acc:0.7107
# epoch:167, train acc:0.8833333333333333, test acc:0.7121
# epoch:168, train acc:0.8966666666666666, test acc:0.7135
# epoch:169, train acc:0.8833333333333333, test acc:0.7155
# epoch:170, train acc:0.9033333333333333, test acc:0.7126
# epoch:171, train acc:0.89, test acc:0.7093
# epoch:172, train acc:0.8733333333333333, test acc:0.7098
# epoch:173, train acc:0.8766666666666667, test acc:0.7116
# epoch:174, train acc:0.8966666666666666, test acc:0.7091
# epoch:175, train acc:0.9033333333333333, test acc:0.7224
# epoch:176, train acc:0.9133333333333333, test acc:0.7185
# epoch:177, train acc:0.8866666666666667, test acc:0.7064
# epoch:178, train acc:0.8966666666666666, test acc:0.7161
# epoch:179, train acc:0.9066666666666666, test acc:0.7154
# epoch:180, train acc:0.9133333333333333, test acc:0.7209
# epoch:181, train acc:0.9033333333333333, test acc:0.7167
# epoch:182, train acc:0.8933333333333333, test acc:0.7172
# epoch:183, train acc:0.8933333333333333, test acc:0.719
# epoch:184, train acc:0.89, test acc:0.7197
# epoch:185, train acc:0.8866666666666667, test acc:0.7116
# epoch:186, train acc:0.88, test acc:0.7161
# epoch:187, train acc:0.88, test acc:0.7138
# epoch:188, train acc:0.9066666666666666, test acc:0.7226
# epoch:189, train acc:0.9033333333333333, test acc:0.7146
# epoch:190, train acc:0.9033333333333333, test acc:0.7248
# epoch:191, train acc:0.8966666666666666, test acc:0.7201
# epoch:192, train acc:0.9, test acc:0.7243
# epoch:193, train acc:0.91, test acc:0.7206
# epoch:194, train acc:0.9066666666666666, test acc:0.7206
# epoch:195, train acc:0.91, test acc:0.7246
# epoch:196, train acc:0.9166666666666666, test acc:0.722
# epoch:197, train acc:0.9066666666666666, test acc:0.7281
# epoch:198, train acc:0.91, test acc:0.7246
# epoch:199, train acc:0.9, test acc:0.7265
# epoch:200, train acc:0.9133333333333333, test acc:0.7289

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비울 설정 ========================
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.3141240048141656
# === epoch:1, train acc:0.06666666666666667, test acc:0.0754 ===
# train loss:2.3095810009970874
# train loss:2.3171802988998196
# train loss:2.3050932133889086
# === epoch:2, train acc:0.07, test acc:0.076 ===
# train loss:2.3034927925587785
# train loss:2.297791322306078
# train loss:2.311036492590061
# === epoch:3, train acc:0.06666666666666667, test acc:0.0785 ===
# train loss:2.3049449307262266
# train loss:2.2996957381487895
# train loss:2.2862847097536156
# === epoch:4, train acc:0.07333333333333333, test acc:0.0813 ===
# train loss:2.2898692385989907
# train loss:2.2950431024028433
# train loss:2.295630594337299
# === epoch:5, train acc:0.08666666666666667, test acc:0.0826 ===
# train loss:2.3024626928286382
# train loss:2.301028347231215
# train loss:2.2955958531092366
# === epoch:6, train acc:0.08666666666666667, test acc:0.0852 ===
# train loss:2.303485930750845
# train loss:2.2959451728307254
# train loss:2.294860078958319
# === epoch:7, train acc:0.09666666666666666, test acc:0.0868 ===
# train loss:2.3034394263444122
# train loss:2.300635271319975
# train loss:2.29506011964349
# === epoch:8, train acc:0.1, test acc:0.0888 ===
# train loss:2.296238904702061
# train loss:2.278960008411565
# train loss:2.3059811110054547
# === epoch:9, train acc:0.11, test acc:0.0929 ===
# train loss:2.2967430475197976
# train loss:2.3106054662112534
# train loss:2.2987269663924734
# === epoch:10, train acc:0.12, test acc:0.0938 ===
# train loss:2.292047093524625
# train loss:2.2915732388478007
# train loss:2.30210920499046
# === epoch:11, train acc:0.11666666666666667, test acc:0.0958 ===
# train loss:2.288093222352855
# train loss:2.300022681535209
# train loss:2.295695361320542
# === epoch:12, train acc:0.11333333333333333, test acc:0.0986 ===
# train loss:2.292030144559233
# train loss:2.3036752033128134
# train loss:2.2802999220039806
# === epoch:13, train acc:0.12, test acc:0.1015 ===
# train loss:2.2851863014883027
# train loss:2.2895347625253706
# train loss:2.2854025041124353
# === epoch:14, train acc:0.11666666666666667, test acc:0.1049 ===
# train loss:2.2902362913439216
# train loss:2.284985914970692
# train loss:2.2917949307619607
# === epoch:15, train acc:0.11666666666666667, test acc:0.111 ===
# train loss:2.293524999381637
# train loss:2.2773213081511137
# train loss:2.2786526627727124
# === epoch:16, train acc:0.13333333333333333, test acc:0.1158 ===
# train loss:2.2901096092646847
# train loss:2.276435445006666
# train loss:2.2739843350599815
# === epoch:17, train acc:0.14, test acc:0.1165 ===
# train loss:2.286017571482133
# train loss:2.2855398880029285
# train loss:2.283296772177954
# === epoch:18, train acc:0.13666666666666666, test acc:0.1205 ===
# train loss:2.2996525869884596
# train loss:2.292483876599823
# train loss:2.2805340888969576
# === epoch:19, train acc:0.15333333333333332, test acc:0.1236 ===
# train loss:2.2827859788774165
# train loss:2.2824782778248554
# train loss:2.27449228380341
# === epoch:20, train acc:0.15333333333333332, test acc:0.1299 ===
# train loss:2.2950123247228134
# train loss:2.28142701803635
# train loss:2.293249610380089
# === epoch:21, train acc:0.16333333333333333, test acc:0.1326 ===
# train loss:2.267376145613857
# train loss:2.273041788788396
# train loss:2.2827542215543257
# === epoch:22, train acc:0.17, test acc:0.137 ===
# train loss:2.2733114254827216
# train loss:2.2842029567943345
# train loss:2.279176275526128
# === epoch:23, train acc:0.17, test acc:0.1401 ===
# train loss:2.285456651534542
# train loss:2.2800974010046806
# train loss:2.2690854162729552
# === epoch:24, train acc:0.16666666666666666, test acc:0.1426 ===
# train loss:2.290117375881587
# train loss:2.2730047838838217
# train loss:2.2701525513686356
# === epoch:25, train acc:0.16666666666666666, test acc:0.1491 ===
# train loss:2.274564471842183
# train loss:2.2796531573542573
# train loss:2.277581771807288
# === epoch:26, train acc:0.17, test acc:0.1511 ===
# train loss:2.256515378900792
# train loss:2.2614426561473873
# train loss:2.2818073960913106
# === epoch:27, train acc:0.18333333333333332, test acc:0.1527 ===
# train loss:2.269058784589564
# train loss:2.2627134859247717
# train loss:2.270481886421435
# === epoch:28, train acc:0.19, test acc:0.1586 ===
# train loss:2.2802289415181987
# train loss:2.2780188371043564
# train loss:2.274527176543142
# === epoch:29, train acc:0.19666666666666666, test acc:0.164 ===
# train loss:2.267484781903648
# train loss:2.2737131394971173
# train loss:2.2743812301549764
# === epoch:30, train acc:0.19, test acc:0.1661 ===
# train loss:2.2678109042054406
# train loss:2.2662874197866034
# train loss:2.263490394452772
# === epoch:31, train acc:0.19666666666666666, test acc:0.1716 ===
# train loss:2.2677333702498625
# train loss:2.2697831977481546
# train loss:2.2720578739716455
# === epoch:32, train acc:0.20333333333333334, test acc:0.1746 ===
# train loss:2.271370341089922
# train loss:2.275883557823592
# train loss:2.2725620281181875
# === epoch:33, train acc:0.21, test acc:0.1789 ===
# train loss:2.2813899293172
# train loss:2.2615967726131445
# train loss:2.270831720777482
# === epoch:34, train acc:0.20666666666666667, test acc:0.1813 ===
# train loss:2.27213578777582
# train loss:2.2715805365108666
# train loss:2.2879602569293356
# === epoch:35, train acc:0.21, test acc:0.1854 ===
# train loss:2.280529151818446
# train loss:2.2574258573696016
# train loss:2.2756972009881853
# === epoch:36, train acc:0.21666666666666667, test acc:0.1903 ===
# train loss:2.2720635723099885
# train loss:2.259334796584025
# train loss:2.2707658752123283
# === epoch:37, train acc:0.21666666666666667, test acc:0.1922 ===
# train loss:2.2685982379310037
# train loss:2.2672498237146796
# train loss:2.269780606215834
# === epoch:38, train acc:0.23, test acc:0.1976 ===
# train loss:2.2698504899028524
# train loss:2.2616043869783202
# train loss:2.265212520692357
# === epoch:39, train acc:0.23666666666666666, test acc:0.2025 ===
# train loss:2.256635941155414
# train loss:2.262871353165858
# train loss:2.271671905706037
# === epoch:40, train acc:0.24, test acc:0.2067 ===
# train loss:2.263907118624287
# train loss:2.2621372373531305
# train loss:2.248759251773422
# === epoch:41, train acc:0.24, test acc:0.2056 ===
# train loss:2.2532130237846664
# train loss:2.256315667651097
# train loss:2.270362776254649
# === epoch:42, train acc:0.24, test acc:0.2092 ===
# train loss:2.248240326709124
# train loss:2.2740880379126645
# train loss:2.261836352959901
# === epoch:43, train acc:0.24333333333333335, test acc:0.2132 ===
# train loss:2.2697999475296773
# train loss:2.2653955444396714
# train loss:2.263989970573824
# === epoch:44, train acc:0.24666666666666667, test acc:0.2133 ===
# train loss:2.2642589756017646
# train loss:2.2508002375449285
# train loss:2.2810991734700488
# === epoch:45, train acc:0.25, test acc:0.216 ===
# train loss:2.2390289954806675
# train loss:2.2675596310076087
# train loss:2.242117318402327
# === epoch:46, train acc:0.24333333333333335, test acc:0.2184 ===
# train loss:2.250398467926094
# train loss:2.2760870129471122
# train loss:2.247878304107145
# === epoch:47, train acc:0.25333333333333335, test acc:0.2233 ===
# train loss:2.256349937316747
# train loss:2.263112469144893
# train loss:2.25089490947894
# === epoch:48, train acc:0.26, test acc:0.228 ===
# train loss:2.270983391610764
# train loss:2.2595470881842834
# train loss:2.262539443506149
# === epoch:49, train acc:0.2866666666666667, test acc:0.2335 ===
# train loss:2.25458684748996
# train loss:2.2612894280457776
# train loss:2.244547080049056
# === epoch:50, train acc:0.2866666666666667, test acc:0.234 ===
# train loss:2.2600890298454104
# train loss:2.2544803294535014
# train loss:2.265387554251512
# === epoch:51, train acc:0.2866666666666667, test acc:0.2355 ===
# train loss:2.2605463548867393
# train loss:2.2473682923191287
# train loss:2.2559235655678584
# === epoch:52, train acc:0.27666666666666667, test acc:0.2349 ===
# train loss:2.231713981313982
# train loss:2.2517847668265274
# train loss:2.2681011326889142
# === epoch:53, train acc:0.3, test acc:0.2387 ===
# train loss:2.2786328153049764
# train loss:2.25316114513401
# train loss:2.2452315864697856
# === epoch:54, train acc:0.29, test acc:0.2395 ===
# train loss:2.261781399924735
# train loss:2.249275951377388
# train loss:2.262177789563122
# === epoch:55, train acc:0.2966666666666667, test acc:0.2414 ===
# train loss:2.284506976079048
# train loss:2.25642207577672
# train loss:2.236417347686777
# === epoch:56, train acc:0.30333333333333334, test acc:0.2439 ===
# train loss:2.2462326179543863
# train loss:2.235320357378722
# train loss:2.2386406825762806
# === epoch:57, train acc:0.29333333333333333, test acc:0.2452 ===
# train loss:2.2569262784075175
# train loss:2.2431798839665986
# train loss:2.23643733997368
# === epoch:58, train acc:0.2966666666666667, test acc:0.2454 ===
# train loss:2.2394558516177074
# train loss:2.244367846699163
# train loss:2.2535161267660775
# === epoch:59, train acc:0.30333333333333334, test acc:0.2455 ===
# train loss:2.2376660693831143
# train loss:2.237712159956567
# train loss:2.257877508217325
# === epoch:60, train acc:0.3, test acc:0.2462 ===
# train loss:2.237258688142909
# train loss:2.2399789921348074
# train loss:2.242681686751471
# === epoch:61, train acc:0.30333333333333334, test acc:0.2489 ===
# train loss:2.2607463658835796
# train loss:2.263126598522681
# train loss:2.2397271365781344
# === epoch:62, train acc:0.31, test acc:0.2507 ===
# train loss:2.2372439736306875
# train loss:2.2426487454059743
# train loss:2.244478680520297
# === epoch:63, train acc:0.31, test acc:0.2552 ===
# train loss:2.2580255228172
# train loss:2.244441249425318
# train loss:2.224126291504463
# === epoch:64, train acc:0.31333333333333335, test acc:0.2582 ===
# train loss:2.269264627021546
# train loss:2.245160446342092
# train loss:2.232267949807424
# === epoch:65, train acc:0.31333333333333335, test acc:0.2585 ===
# train loss:2.2191544839331736
# train loss:2.2272537294087744
# train loss:2.2520701105697496
# === epoch:66, train acc:0.31, test acc:0.2561 ===
# train loss:2.2300009531938776
# train loss:2.2193131165679127
# train loss:2.2567447936519525
# === epoch:67, train acc:0.30333333333333334, test acc:0.2526 ===
# train loss:2.245602986451229
# train loss:2.215921193523843
# train loss:2.2283379041491718
# === epoch:68, train acc:0.30333333333333334, test acc:0.2517 ===
# train loss:2.2348401844279664
# train loss:2.2363215161673136
# train loss:2.237802937886037
# === epoch:69, train acc:0.30666666666666664, test acc:0.2554 ===
# train loss:2.2653755113243075
# train loss:2.2576639269472025
# train loss:2.235022650104487
# === epoch:70, train acc:0.31333333333333335, test acc:0.2597 ===
# train loss:2.251888709429257
# train loss:2.236965008592077
# train loss:2.2373398399202777
# === epoch:71, train acc:0.31666666666666665, test acc:0.2631 ===
# train loss:2.2201812681521216
# train loss:2.2414071974430123
# train loss:2.252977820809299
# === epoch:72, train acc:0.3233333333333333, test acc:0.2635 ===
# train loss:2.236014093396866
# train loss:2.227565927355806
# train loss:2.217790214986622
# === epoch:73, train acc:0.31666666666666665, test acc:0.2629 ===
# train loss:2.2417153640223564
# train loss:2.2389737842958013
# train loss:2.2062689787530814
# === epoch:74, train acc:0.32, test acc:0.2635 ===
# train loss:2.230006057763013
# train loss:2.2064789401952867
# train loss:2.2340910401522267
# === epoch:75, train acc:0.31666666666666665, test acc:0.2607 ===
# train loss:2.230918309159888
# train loss:2.2199407707379466
# train loss:2.2145978573856233
# === epoch:76, train acc:0.32, test acc:0.2605 ===
# train loss:2.195413377511154
# train loss:2.2226674946220553
# train loss:2.2009834169805575
# === epoch:77, train acc:0.32666666666666666, test acc:0.2558 ===
# train loss:2.2141531275666355
# train loss:2.214248081142064
# train loss:2.2337160006982413
# === epoch:78, train acc:0.33, test acc:0.2579 ===
# train loss:2.2260844987878534
# train loss:2.239326698142939
# train loss:2.2279723999432606
# === epoch:79, train acc:0.33, test acc:0.2613 ===
# train loss:2.226078109767883
# train loss:2.195908933886363
# train loss:2.2178794783556866
# === epoch:80, train acc:0.33, test acc:0.2616 ===
# train loss:2.2268238680572776
# train loss:2.2417402958271673
# train loss:2.2510742612773775
# === epoch:81, train acc:0.33, test acc:0.2637 ===
# train loss:2.251864622753433
# train loss:2.2166931054689485
# train loss:2.209044033763534
# === epoch:82, train acc:0.3333333333333333, test acc:0.268 ===
# train loss:2.234273714221988
# train loss:2.2245954142338875
# train loss:2.231289343936967
# === epoch:83, train acc:0.34, test acc:0.2712 ===
# train loss:2.220334100042516
# train loss:2.250920489798231
# train loss:2.180171006923455
# === epoch:84, train acc:0.34, test acc:0.273 ===
# train loss:2.2398546124231316
# train loss:2.2384161923527928
# train loss:2.2182800232348487
# === epoch:85, train acc:0.3433333333333333, test acc:0.2749 ===
# train loss:2.2284061201095495
# train loss:2.2107917589595343
# train loss:2.2302649283999205
# === epoch:86, train acc:0.34, test acc:0.2768 ===
# train loss:2.2394476424781984
# train loss:2.208115160952134
# train loss:2.2121929710234114
# === epoch:87, train acc:0.3433333333333333, test acc:0.2778 ===
# train loss:2.246249855719847
# train loss:2.224257388446675
# train loss:2.1846626017346784
# === epoch:88, train acc:0.3433333333333333, test acc:0.2781 ===
# train loss:2.1985480784852793
# train loss:2.252422090155505
# train loss:2.194720500191926
# === epoch:89, train acc:0.3466666666666667, test acc:0.281 ===
# train loss:2.199674153154128
# train loss:2.2426313406735114
# train loss:2.196805175417933
# === epoch:90, train acc:0.3466666666666667, test acc:0.2815 ===
# train loss:2.2062109630805504
# train loss:2.2427124984847855
# train loss:2.172380867476302
# === epoch:91, train acc:0.35, test acc:0.2814 ===
# train loss:2.2110854128619146
# train loss:2.1961377578508503
# train loss:2.2290447949125918
# === epoch:92, train acc:0.35, test acc:0.2813 ===
# train loss:2.1789921475462957
# train loss:2.217527060717783
# train loss:2.1876765881652585
# === epoch:93, train acc:0.34, test acc:0.2794 ===
# train loss:2.1893834392454687
# train loss:2.1923234910691782
# train loss:2.210603006798377
# === epoch:94, train acc:0.3466666666666667, test acc:0.2807 ===
# train loss:2.225195785027193
# train loss:2.1798149780366685
# train loss:2.21077469529331
# === epoch:95, train acc:0.35333333333333333, test acc:0.2822 ===
# train loss:2.198017792149686
# train loss:2.24661962494341
# train loss:2.1922637751690157
# === epoch:96, train acc:0.35333333333333333, test acc:0.2833 ===
# train loss:2.195478351648346
# train loss:2.202678818863832
# train loss:2.1836412953520306
# === epoch:97, train acc:0.35333333333333333, test acc:0.2826 ===
# train loss:2.2252420034128586
# train loss:2.189149197563155
# train loss:2.1934053690227118
# === epoch:98, train acc:0.35, test acc:0.2835 ===
# train loss:2.214382120267341
# train loss:2.202463267348466
# train loss:2.2009553347394415
# === epoch:99, train acc:0.35333333333333333, test acc:0.2841 ===
# train loss:2.2015797319494808
# train loss:2.1805076171217097
# train loss:2.1698155985709455
# === epoch:100, train acc:0.35333333333333333, test acc:0.2849 ===
# train loss:2.200882635019221
# train loss:2.1464390330625833
# train loss:2.199696730362429
# === epoch:101, train acc:0.35, test acc:0.2845 ===
# train loss:2.1933937769804865
# train loss:2.1733785036962163
# train loss:2.1546027754598516
# === epoch:102, train acc:0.35, test acc:0.2825 ===
# train loss:2.1907774879604096
# train loss:2.194145134954142
# train loss:2.2201640476878417
# === epoch:103, train acc:0.35, test acc:0.2856 ===
# train loss:2.2124237694242335
# train loss:2.20594807617705
# train loss:2.1758786198798425
# === epoch:104, train acc:0.35, test acc:0.2881 ===
# train loss:2.192007521872769
# train loss:2.1661087649392696
# train loss:2.1589339661333597
# === epoch:105, train acc:0.35, test acc:0.2861 ===
# train loss:2.19787757807157
# train loss:2.150028466079965
# train loss:2.198823258330592
# === epoch:106, train acc:0.35, test acc:0.2867 ===
# train loss:2.1739610538328673
# train loss:2.2106252753827107
# train loss:2.1545296046045137
# === epoch:107, train acc:0.35, test acc:0.2862 ===
# train loss:2.195917514915922
# train loss:2.1756684161429094
# train loss:2.170457091187904
# === epoch:108, train acc:0.35, test acc:0.2871 ===
# train loss:2.185342990121552
# train loss:2.147098772743103
# train loss:2.1690322428590023
# === epoch:109, train acc:0.35333333333333333, test acc:0.2883 ===
# train loss:2.1759213184287667
# train loss:2.1850428340082475
# train loss:2.1435231235789947
# === epoch:110, train acc:0.3566666666666667, test acc:0.2879 ===
# train loss:2.164461202992403
# train loss:2.1649243244607272
# train loss:2.188740344164845
# === epoch:111, train acc:0.3566666666666667, test acc:0.2886 ===
# train loss:2.1277503703581155
# train loss:2.1747656122663868
# train loss:2.166588946676819
# === epoch:112, train acc:0.3566666666666667, test acc:0.29 ===
# train loss:2.1420949428213616
# train loss:2.1766404218259976
# train loss:2.178949534242071
# === epoch:113, train acc:0.3566666666666667, test acc:0.2898 ===
# train loss:2.1412288320805306
# train loss:2.2057537717971725
# train loss:2.1587814419242797
# === epoch:114, train acc:0.36, test acc:0.2909 ===
# train loss:2.1723422699144526
# train loss:2.1087649944669047
# train loss:2.098244674622503
# === epoch:115, train acc:0.3566666666666667, test acc:0.2891 ===
# train loss:2.146197984914702
# train loss:2.131388571601666
# train loss:2.191353977039235
# === epoch:116, train acc:0.36, test acc:0.2902 ===
# train loss:2.1464680156774976
# train loss:2.1465600200970933
# train loss:2.1206544421782385
# === epoch:117, train acc:0.3566666666666667, test acc:0.2899 ===
# train loss:2.1430588275852456
# train loss:2.129924303381433
# train loss:2.1247842197667866
# === epoch:118, train acc:0.36333333333333334, test acc:0.2903 ===
# train loss:2.0943538911326467
# train loss:2.193930478474978
# train loss:2.148683397473219
# === epoch:119, train acc:0.36, test acc:0.29 ===
# train loss:2.136540330920183
# train loss:2.10953854587965
# train loss:2.1138782498064153
# === epoch:120, train acc:0.36, test acc:0.2868 ===
# train loss:2.1421777737586654
# train loss:2.147127014257211
# train loss:2.1211773480640335
# === epoch:121, train acc:0.36, test acc:0.2872 ===
# train loss:2.135475848528101
# train loss:2.129400474630899
# train loss:2.123644969826486
# === epoch:122, train acc:0.36, test acc:0.2867 ===
# train loss:2.1333214636523348
# train loss:2.1801673647862367
# train loss:2.1334070500153706
# === epoch:123, train acc:0.36, test acc:0.2869 ===
# train loss:2.0938523795530477
# train loss:2.107354131470197
# train loss:2.111261716615584
# === epoch:124, train acc:0.3566666666666667, test acc:0.2847 ===
# train loss:2.064314813995166
# train loss:2.204687592616368
# train loss:2.0825037569144724
# === epoch:125, train acc:0.3566666666666667, test acc:0.2832 ===
# train loss:2.1378080724757136
# train loss:2.1339282537795365
# train loss:2.1522057691575434
# === epoch:126, train acc:0.3566666666666667, test acc:0.2821 ===
# train loss:2.195881558161665
# train loss:2.1378617791783605
# train loss:2.174311076704788
# === epoch:127, train acc:0.36, test acc:0.2846 ===
# train loss:2.0651150754359078
# train loss:2.124482402792845
# train loss:2.1299335247186613
# === epoch:128, train acc:0.3566666666666667, test acc:0.2844 ===
# train loss:2.088313103718325
# train loss:2.1210133333573298
# train loss:2.1040813164712193
# === epoch:129, train acc:0.36, test acc:0.2845 ===
# train loss:2.086178185405061
# train loss:2.1130927284865355
# train loss:2.145615557597218
# === epoch:130, train acc:0.36, test acc:0.2865 ===
# train loss:2.101766670772219
# train loss:2.150127723858005
# train loss:2.0694943306813234
# === epoch:131, train acc:0.36, test acc:0.2883 ===
# train loss:2.129529922625218
# train loss:2.106267320808497
# train loss:2.0875096850296253
# === epoch:132, train acc:0.36, test acc:0.2886 ===
# train loss:1.9700184394702491
# train loss:2.1020191507089327
# train loss:2.123608542470204
# === epoch:133, train acc:0.36, test acc:0.287 ===
# train loss:2.1033678278198162
# train loss:2.1228487216048437
# train loss:2.0603494619886784
# === epoch:134, train acc:0.36, test acc:0.289 ===
# train loss:2.1515571551233914
# train loss:2.1456541711397144
# train loss:2.0433429698072474
# === epoch:135, train acc:0.36333333333333334, test acc:0.2893 ===
# train loss:2.0634306213519116
# train loss:2.0959443474554735
# train loss:2.139616880305972
# === epoch:136, train acc:0.36333333333333334, test acc:0.2898 ===
# train loss:2.058868282420041
# train loss:2.0860079388549972
# train loss:2.1211354003329164
# === epoch:137, train acc:0.36666666666666664, test acc:0.2924 ===
# train loss:2.1207288462108256
# train loss:2.0816217953478553
# train loss:2.0473354211050023
# === epoch:138, train acc:0.37, test acc:0.2977 ===
# train loss:2.1230124029997395
# train loss:2.072964672780859
# train loss:2.0742081502549437
# === epoch:139, train acc:0.37333333333333335, test acc:0.2987 ===
# train loss:2.108225507912264
# train loss:2.086622120720548
# train loss:2.0568279935531195
# === epoch:140, train acc:0.37, test acc:0.2994 ===
# train loss:2.075278117125943
# train loss:2.029325361746322
# train loss:2.1073439662908013
# === epoch:141, train acc:0.37333333333333335, test acc:0.302 ===
# train loss:2.0828993709897903
# train loss:2.1349217103612137
# train loss:2.094680541021324
# === epoch:142, train acc:0.38, test acc:0.3052 ===
# train loss:2.087813814409489
# train loss:2.086101467182108
# train loss:2.154002754671166
# === epoch:143, train acc:0.38, test acc:0.3062 ===
# train loss:2.0706958389907277
# train loss:2.0802994357241698
# train loss:2.0996094817561657
# === epoch:144, train acc:0.38, test acc:0.3048 ===
# train loss:2.0456727382179305
# train loss:2.0426426466361556
# train loss:2.046678505848631
# === epoch:145, train acc:0.38, test acc:0.3051 ===
# train loss:2.045219271069035
# train loss:2.0393075077514844
# train loss:2.0240220787045025
# === epoch:146, train acc:0.38, test acc:0.3047 ===
# train loss:2.059430436104988
# train loss:2.0990392557999633
# train loss:2.0785489606371357
# === epoch:147, train acc:0.38, test acc:0.3039 ===
# train loss:2.0058613250456316
# train loss:2.0639615014460992
# train loss:2.0617860317066246
# === epoch:148, train acc:0.38333333333333336, test acc:0.3061 ===
# train loss:2.0889951226386443
# train loss:1.9877960397178835
# train loss:2.101200513685805
# === epoch:149, train acc:0.39, test acc:0.3074 ===
# train loss:2.0560379655261802
# train loss:2.0999993322059116
# train loss:2.0897432743688444
# === epoch:150, train acc:0.39666666666666667, test acc:0.3125 ===
# train loss:1.992244926367735
# train loss:2.0182929585270246
# train loss:2.0633011748685126
# === epoch:151, train acc:0.3933333333333333, test acc:0.3115 ===
# train loss:1.9671285677854322
# train loss:1.991435977316457
# train loss:2.1134180527401543
# === epoch:152, train acc:0.39666666666666667, test acc:0.3146 ===
# train loss:1.9903869628289983
# train loss:1.945621675472838
# train loss:2.0991987612167025
# === epoch:153, train acc:0.39666666666666667, test acc:0.3158 ===
# train loss:2.0685728888921178
# train loss:2.0764981993206018
# train loss:2.0074986008873807
# === epoch:154, train acc:0.4, test acc:0.3193 ===
# train loss:2.0455068886028216
# train loss:1.9177274146198977
# train loss:1.9696333009579052
# === epoch:155, train acc:0.4, test acc:0.3194 ===
# train loss:2.0222213719976416
# train loss:2.029600857987658
# train loss:1.9836054738590843
# === epoch:156, train acc:0.4, test acc:0.3216 ===
# train loss:1.9677887523450073
# train loss:1.9270838862182313
# train loss:2.0367015654064122
# === epoch:157, train acc:0.3933333333333333, test acc:0.3177 ===
# train loss:1.9589947151618512
# train loss:2.020672073702481
# train loss:2.0129589932930925
# === epoch:158, train acc:0.3933333333333333, test acc:0.3198 ===
# train loss:2.0812723009365497
# train loss:2.03183499132071
# train loss:2.0677819209415005
# === epoch:159, train acc:0.3933333333333333, test acc:0.3244 ===
# train loss:2.017663594523033
# train loss:2.0010417810843286
# train loss:2.050361936940169
# === epoch:160, train acc:0.4, test acc:0.3284 ===
# train loss:2.002563556356887
# train loss:2.0593308371684294
# train loss:2.028464992014978
# === epoch:161, train acc:0.4, test acc:0.3319 ===
# train loss:2.0457074725359266
# train loss:1.9387719173288627
# train loss:1.9279098117500184
# === epoch:162, train acc:0.4, test acc:0.3314 ===
# train loss:2.018257727119691
# train loss:1.9495934685886924
# train loss:2.0849860627183427
# === epoch:163, train acc:0.4, test acc:0.334 ===
# train loss:2.0446051361717767
# train loss:2.0510173390178417
# train loss:1.866416487737431
# === epoch:164, train acc:0.4, test acc:0.3376 ===
# train loss:2.007376330414348
# train loss:2.0476525169972004
# train loss:1.9521897110899296
# === epoch:165, train acc:0.4066666666666667, test acc:0.3409 ===
# train loss:1.9605840185094783
# train loss:1.9000936001393705
# train loss:1.9570856512703363
# === epoch:166, train acc:0.4066666666666667, test acc:0.3422 ===
# train loss:2.0462306695547205
# train loss:2.0010278407935282
# train loss:1.9719793886345582
# === epoch:167, train acc:0.4066666666666667, test acc:0.346 ===
# train loss:2.0298533605284517
# train loss:1.9676133222729002
# train loss:2.06971729665924
# === epoch:168, train acc:0.42, test acc:0.3536 ===
# train loss:2.0624432102388877
# train loss:1.8667577416592258
# train loss:2.003494197070059
# === epoch:169, train acc:0.42, test acc:0.3547 ===
# train loss:2.0413998657998285
# train loss:2.01155926918995
# train loss:1.9587768906763625
# === epoch:170, train acc:0.43, test acc:0.3626 ===
# train loss:1.9077762050837521
# train loss:2.001150380885103
# train loss:1.9880480953738606
# === epoch:171, train acc:0.4266666666666667, test acc:0.3605 ===
# train loss:2.0480679642155453
# train loss:1.9420197862317892
# train loss:1.9741538837277
# === epoch:172, train acc:0.43333333333333335, test acc:0.3632 ===
# train loss:1.8892628521076968
# train loss:1.9564874902844829
# train loss:1.9691578792689646
# === epoch:173, train acc:0.43333333333333335, test acc:0.361 ===
# train loss:2.0076857751265336
# train loss:1.9548245843566707
# train loss:1.9343664040785173
# === epoch:174, train acc:0.43333333333333335, test acc:0.3638 ===
# train loss:1.8926761023624084
# train loss:1.9950282218313458
# train loss:1.9936278476786482
# === epoch:175, train acc:0.43333333333333335, test acc:0.3645 ===
# train loss:2.003694937918692
# train loss:1.9593606985339744
# train loss:2.011960521045706
# === epoch:176, train acc:0.43333333333333335, test acc:0.3676 ===
# train loss:1.8943900669674347
# train loss:1.9855025835573203
# train loss:1.9151146192672757
# === epoch:177, train acc:0.43333333333333335, test acc:0.368 ===
# train loss:2.0128247743144403
# train loss:1.995057155075493
# train loss:1.9490071685875958
# === epoch:178, train acc:0.43, test acc:0.3727 ===
# train loss:1.9975431410811841
# train loss:1.8621503430726631
# train loss:1.9653763797705275
# === epoch:179, train acc:0.43, test acc:0.3709 ===
# train loss:1.95454812475353
# train loss:1.907479644676276
# train loss:1.9691104499910832
# === epoch:180, train acc:0.43333333333333335, test acc:0.3707 ===
# train loss:1.9873015496510573
# train loss:1.9992640192957976
# train loss:1.895394346363876
# === epoch:181, train acc:0.43666666666666665, test acc:0.3755 ===
# train loss:2.0304608545460083
# train loss:1.9678146611980176
# train loss:1.917751585623046
# === epoch:182, train acc:0.43333333333333335, test acc:0.3732 ===
# train loss:1.9383039846036605
# train loss:1.8938939815642235
# train loss:1.8646703586764384
# === epoch:183, train acc:0.43333333333333335, test acc:0.3728 ===
# train loss:1.9458622286656706
# train loss:1.9603679920470092
# train loss:2.0424894845326254
# === epoch:184, train acc:0.44333333333333336, test acc:0.3807 ===
# train loss:1.9175073395921263
# train loss:2.0512381331738743
# train loss:1.942937845820215
# === epoch:185, train acc:0.44, test acc:0.3786 ===
# train loss:2.061233620600317
# train loss:1.8753381540457992
# train loss:1.958201626175859
# === epoch:186, train acc:0.44333333333333336, test acc:0.3827 ===
# train loss:1.9259387463166218
# train loss:1.9204235176467201
# train loss:1.967924479709973
# === epoch:187, train acc:0.44333333333333336, test acc:0.3875 ===
# train loss:2.006547325098937
# train loss:1.8373060649786992
# train loss:1.9090590660739122
# === epoch:188, train acc:0.44, test acc:0.3864 ===
# train loss:1.9237808055545274
# train loss:1.8585436017852615
# train loss:1.8980949613918119
# === epoch:189, train acc:0.44333333333333336, test acc:0.386 ===
# train loss:1.959866578874252
# train loss:1.9334139166286153
# train loss:1.8303366183960248
# === epoch:190, train acc:0.44333333333333336, test acc:0.3848 ===
# train loss:1.8755119090053192
# train loss:1.9998050804325203
# train loss:2.0339518356448734
# === epoch:191, train acc:0.44666666666666666, test acc:0.3905 ===
# train loss:1.8280933829415213
# train loss:1.8605196463872278
# train loss:1.8898816270665484
# === epoch:192, train acc:0.44666666666666666, test acc:0.3886 ===
# train loss:1.8800758982017516
# train loss:1.9623047046389148
# train loss:1.8752903186554752
# === epoch:193, train acc:0.44333333333333336, test acc:0.3934 ===
# train loss:1.8965449035458295
# train loss:1.9472683432962594
# train loss:1.874766005672238
# === epoch:194, train acc:0.45, test acc:0.3933 ===
# train loss:1.905596595822129
# train loss:1.9246201571348638
# train loss:1.8389023333752617
# === epoch:195, train acc:0.4533333333333333, test acc:0.3978 ===
# train loss:1.8433658025695174
# train loss:1.9124514390466936
# train loss:1.786082476860465
# === epoch:196, train acc:0.45666666666666667, test acc:0.3986 ===
# train loss:1.912489225323483
# train loss:1.8365490592562734
# train loss:1.9327964678763092
# === epoch:197, train acc:0.4533333333333333, test acc:0.4004 ===
# train loss:1.9060859234685577
# train loss:1.8875277070621927
# train loss:1.9142543366213507
# === epoch:198, train acc:0.4533333333333333, test acc:0.4012 ===
# train loss:1.9227548243097683
# train loss:1.8160384019058955
# train loss:1.8549874243587832
# === epoch:199, train acc:0.46, test acc:0.4001 ===
# train loss:1.7750463259760603
# train loss:1.8064458836133581
# train loss:1.8948535300626301
# === epoch:200, train acc:0.46, test acc:0.3959 ===
# train loss:1.7865288691219825
# train loss:1.8811420903034253
# train loss:1.8469304781465792
# === epoch:201, train acc:0.4633333333333333, test acc:0.4008 ===
# train loss:1.7517381760198032
# train loss:1.7921483833541874
# train loss:1.8089640121848434
# === epoch:202, train acc:0.46, test acc:0.404 ===
# train loss:1.9242598085570257
# train loss:1.7195035398900729
# train loss:1.8550800361479296
# === epoch:203, train acc:0.4633333333333333, test acc:0.4026 ===
# train loss:1.8549059965756445
# train loss:1.9285698850249435
# train loss:1.8651240073528004
# === epoch:204, train acc:0.4666666666666667, test acc:0.4078 ===
# train loss:1.8908606154047303
# train loss:1.7319467246617328
# train loss:1.91484482293914
# === epoch:205, train acc:0.4666666666666667, test acc:0.4091 ===
# train loss:2.0278072247063657
# train loss:1.8653590497446493
# train loss:1.8411304353918638
# === epoch:206, train acc:0.47333333333333333, test acc:0.4151 ===
# train loss:1.8205140706737404
# train loss:1.8257100154800954
# train loss:1.8703288466684116
# === epoch:207, train acc:0.47333333333333333, test acc:0.4173 ===
# train loss:1.816293143512093
# train loss:1.7095909589288232
# train loss:1.8988862487842366
# === epoch:208, train acc:0.47333333333333333, test acc:0.4151 ===
# train loss:1.899638140628387
# train loss:1.800352607912693
# train loss:1.8344346633073332
# === epoch:209, train acc:0.4766666666666667, test acc:0.4154 ===
# train loss:1.8319898521758275
# train loss:1.932477851567656
# train loss:1.8808012357535262
# === epoch:210, train acc:0.48, test acc:0.416 ===
# train loss:1.841885481015742
# train loss:1.7721037106974546
# train loss:1.9738876384419652
# === epoch:211, train acc:0.48333333333333334, test acc:0.4162 ===
# train loss:1.6895281640942685
# train loss:1.8130191993330467
# train loss:1.7801575942511214
# === epoch:212, train acc:0.48333333333333334, test acc:0.4192 ===
# train loss:1.8243841541340677
# train loss:1.8766761789232378
# train loss:1.7137239250056597
# === epoch:213, train acc:0.48333333333333334, test acc:0.4166 ===
# train loss:1.9094214707582022
# train loss:1.750012954379625
# train loss:1.7888960352089427
# === epoch:214, train acc:0.48333333333333334, test acc:0.4201 ===
# train loss:1.71277402168653
# train loss:1.741865899956195
# train loss:1.8584553162303359
# === epoch:215, train acc:0.4866666666666667, test acc:0.4217 ===
# train loss:1.9321345961484306
# train loss:1.8006874105804402
# train loss:1.8137389620412592
# === epoch:216, train acc:0.4866666666666667, test acc:0.4248 ===
# train loss:1.7912344075176727
# train loss:1.8525028027722852
# train loss:1.8794192843492825
# === epoch:217, train acc:0.48333333333333334, test acc:0.4284 ===
# train loss:1.8636833086375153
# train loss:1.7211105967317086
# train loss:1.8477860743450334
# === epoch:218, train acc:0.4866666666666667, test acc:0.4299 ===
# train loss:1.9064945678520917
# train loss:1.7513105209834565
# train loss:1.8197866769457647
# === epoch:219, train acc:0.4866666666666667, test acc:0.43 ===
# train loss:1.8227122122913175
# train loss:1.7853765085272304
# train loss:1.7812894965283232
# === epoch:220, train acc:0.48333333333333334, test acc:0.4327 ===
# train loss:1.7683881461041309
# train loss:1.7877146131942436
# train loss:1.7306108999652048
# === epoch:221, train acc:0.48333333333333334, test acc:0.4336 ===
# train loss:1.8655176310598864
# train loss:1.7246958908215526
# train loss:1.9502236525920593
# === epoch:222, train acc:0.4866666666666667, test acc:0.436 ===
# train loss:1.8025955722632683
# train loss:1.6488432326780702
# train loss:1.7361423681078645
# === epoch:223, train acc:0.49333333333333335, test acc:0.4367 ===
# train loss:1.628962346233046
# train loss:1.7957825325050618
# train loss:1.7613369121646054
# === epoch:224, train acc:0.49, test acc:0.4325 ===
# train loss:1.8569850321883608
# train loss:1.7085189775790053
# train loss:1.7542529245084486
# === epoch:225, train acc:0.4866666666666667, test acc:0.4374 ===
# train loss:1.7957499126436585
# train loss:1.7955271630327538
# train loss:1.6747815310661045
# === epoch:226, train acc:0.4866666666666667, test acc:0.4419 ===
# train loss:1.8394337957751434
# train loss:1.730672732299236
# train loss:1.7580227698208004
# === epoch:227, train acc:0.49, test acc:0.4445 ===
# train loss:1.6750504516793316
# train loss:1.6548577350303324
# train loss:1.860529705598938
# === epoch:228, train acc:0.49666666666666665, test acc:0.4455 ===
# train loss:1.7518916714784734
# train loss:1.8296112366873098
# train loss:1.753284874386109
# === epoch:229, train acc:0.49333333333333335, test acc:0.4424 ===
# train loss:1.7430995074175808
# train loss:1.7928322821633298
# train loss:1.7520826917589398
# === epoch:230, train acc:0.49, test acc:0.4432 ===
# train loss:1.7622058859534
# train loss:1.6138025206201
# train loss:1.7639393442297533
# === epoch:231, train acc:0.5, test acc:0.447 ===
# train loss:1.8947677927359965
# train loss:1.8998343960114012
# train loss:1.8734554843821813
# === epoch:232, train acc:0.5066666666666667, test acc:0.4553 ===
# train loss:1.6745004068553297
# train loss:1.7791191261447927
# train loss:1.713970171426846
# === epoch:233, train acc:0.51, test acc:0.4567 ===
# train loss:1.740032092510929
# train loss:1.7546936631343732
# train loss:1.781997064360358
# === epoch:234, train acc:0.51, test acc:0.4589 ===
# train loss:1.7777898178885667
# train loss:1.7208294989411066
# train loss:1.9300936598044154
# === epoch:235, train acc:0.5166666666666667, test acc:0.4608 ===
# train loss:1.703605188948321
# train loss:1.791245832103112
# train loss:1.8647940806456775
# === epoch:236, train acc:0.5066666666666667, test acc:0.4619 ===
# train loss:1.730233921661145
# train loss:1.6948086905902437
# train loss:1.7864434148618917
# === epoch:237, train acc:0.52, test acc:0.4622 ===
# train loss:1.585160514210854
# train loss:1.732278600747143
# train loss:1.6011700721519488
# === epoch:238, train acc:0.52, test acc:0.4627 ===
# train loss:1.6461103895871283
# train loss:1.6805053387010247
# train loss:1.7138109183444246
# === epoch:239, train acc:0.5166666666666667, test acc:0.4642 ===
# train loss:1.745031199593013
# train loss:1.6296144814270483
# train loss:1.7890473283779358
# === epoch:240, train acc:0.52, test acc:0.4656 ===
# train loss:1.7255801496043965
# train loss:1.8791457895998027
# train loss:1.7009041860335166
# === epoch:241, train acc:0.53, test acc:0.4678 ===
# train loss:1.6784471402267278
# train loss:1.7529860246379005
# train loss:1.7454975608873224
# === epoch:242, train acc:0.53, test acc:0.4675 ===
# train loss:1.5690874954673728
# train loss:1.7124041106275039
# train loss:1.7273906832191757
# === epoch:243, train acc:0.53, test acc:0.4668 ===
# train loss:1.7927384487799791
# train loss:1.7518442578119238
# train loss:1.6555265354744682
# === epoch:244, train acc:0.53, test acc:0.4701 ===
# train loss:1.6480981841078282
# train loss:1.633944274705582
# train loss:1.619701207158004
# === epoch:245, train acc:0.5266666666666666, test acc:0.4735 ===
# train loss:1.6893555607475677
# train loss:1.715263501107471
# train loss:1.8187410480027102
# === epoch:246, train acc:0.5266666666666666, test acc:0.4799 ===
# train loss:1.6424231117347743
# train loss:1.5505112041192066
# train loss:1.6881465001078328
# === epoch:247, train acc:0.53, test acc:0.4771 ===
# train loss:1.6894254446568953
# train loss:1.661423187114729
# train loss:1.6255831477090015
# === epoch:248, train acc:0.5366666666666666, test acc:0.4789 ===
# train loss:1.7023899185461076
# train loss:1.7426464419951333
# train loss:1.7482653912376498
# === epoch:249, train acc:0.5333333333333333, test acc:0.4785 ===
# train loss:1.7701518957121807
# train loss:1.7230588441548562
# train loss:1.573812044071441
# === epoch:250, train acc:0.5333333333333333, test acc:0.4783 ===
# train loss:1.7886788465766663
# train loss:1.626706385648879
# train loss:1.6458488852263722
# === epoch:251, train acc:0.5333333333333333, test acc:0.4799 ===
# train loss:1.5823814264407934
# train loss:1.6445652340732755
# train loss:1.7791358984691756
# === epoch:252, train acc:0.53, test acc:0.483 ===
# train loss:1.6202525824178986
# train loss:1.632235203692656
# train loss:1.7035377009723962
# === epoch:253, train acc:0.53, test acc:0.4845 ===
# train loss:1.6826075644739686
# train loss:1.6773391376040936
# train loss:1.5482792259845133
# === epoch:254, train acc:0.53, test acc:0.4832 ===
# train loss:1.668160878074329
# train loss:1.6240714493139219
# train loss:1.746397863685995
# === epoch:255, train acc:0.5333333333333333, test acc:0.4838 ===
# train loss:1.6689550077501583
# train loss:1.5955424897436172
# train loss:1.7072703103692575
# === epoch:256, train acc:0.5366666666666666, test acc:0.4875 ===
# train loss:1.690974049299156
# train loss:1.575585111831497
# train loss:1.5559327378109673
# === epoch:257, train acc:0.5333333333333333, test acc:0.4851 ===
# train loss:1.7331049646958316
# train loss:1.6275715040099081
# train loss:1.837846519700264
# === epoch:258, train acc:0.5333333333333333, test acc:0.4855 ===
# train loss:1.5914572857054607
# train loss:1.6499858742666644
# train loss:1.6447710746411495
# === epoch:259, train acc:0.5366666666666666, test acc:0.4856 ===
# train loss:1.6019294959017325
# train loss:1.6688749070132045
# train loss:1.6445559266375556
# === epoch:260, train acc:0.5366666666666666, test acc:0.4913 ===
# train loss:1.543342706634887
# train loss:1.502506061930934
# train loss:1.7697449470314106
# === epoch:261, train acc:0.5366666666666666, test acc:0.4924 ===
# train loss:1.7662607484824564
# train loss:1.693414377853793
# train loss:1.5040395004953808
# === epoch:262, train acc:0.54, test acc:0.4955 ===
# train loss:1.5284342566919926
# train loss:1.6722981339145548
# train loss:1.5882039642534265
# === epoch:263, train acc:0.54, test acc:0.4944 ===
# train loss:1.6527828018361237
# train loss:1.5805912234073858
# train loss:1.5964954309531745
# === epoch:264, train acc:0.5433333333333333, test acc:0.4939 ===
# train loss:1.534495061471687
# train loss:1.58460877222548
# train loss:1.6118857558868454
# === epoch:265, train acc:0.5366666666666666, test acc:0.4913 ===
# train loss:1.737365807707462
# train loss:1.6312682937667315
# train loss:1.6994214499102807
# === epoch:266, train acc:0.54, test acc:0.495 ===
# train loss:1.6449458712714655
# train loss:1.5571339394870731
# train loss:1.5822871025693064
# === epoch:267, train acc:0.54, test acc:0.499 ===
# train loss:1.6118003764145938
# train loss:1.6323105869698884
# train loss:1.6449042130733929
# === epoch:268, train acc:0.5466666666666666, test acc:0.5026 ===
# train loss:1.5657575968906403
# train loss:1.5198547749367406
# train loss:1.68937673582606
# === epoch:269, train acc:0.56, test acc:0.5033 ===
# train loss:1.5819062659265013
# train loss:1.5443627240569548
# train loss:1.4885407128383654
# === epoch:270, train acc:0.5566666666666666, test acc:0.5037 ===
# train loss:1.7143710743505576
# train loss:1.5135814826263638
# train loss:1.4923677694532262
# === epoch:271, train acc:0.5633333333333334, test acc:0.5041 ===
# train loss:1.6320461641482575
# train loss:1.4862578315407573
# train loss:1.59992141688714
# === epoch:272, train acc:0.5633333333333334, test acc:0.5068 ===
# train loss:1.5163073745369604
# train loss:1.5263165082567367
# train loss:1.61516028074971
# === epoch:273, train acc:0.5666666666666667, test acc:0.5073 ===
# train loss:1.4689333064192331
# train loss:1.6301316927565555
# train loss:1.513527568708667
# === epoch:274, train acc:0.5666666666666667, test acc:0.5084 ===
# train loss:1.603583992294937
# train loss:1.4939189735018599
# train loss:1.4779527858465176
# === epoch:275, train acc:0.5666666666666667, test acc:0.5084 ===
# train loss:1.5518754149117608
# train loss:1.5308077138205964
# train loss:1.601605022000558
# === epoch:276, train acc:0.5666666666666667, test acc:0.5101 ===
# train loss:1.534094930967096
# train loss:1.4753717018383097
# train loss:1.535907911991043
# === epoch:277, train acc:0.57, test acc:0.5105 ===
# train loss:1.481635322304505
# train loss:1.5544641223733502
# train loss:1.5603492224155868
# === epoch:278, train acc:0.5666666666666667, test acc:0.5107 ===
# train loss:1.595712653614032
# train loss:1.581484405591994
# train loss:1.5086378900588324
# === epoch:279, train acc:0.5666666666666667, test acc:0.5105 ===
# train loss:1.5427940515250427
# train loss:1.4614209661167905
# train loss:1.6212018623007929
# === epoch:280, train acc:0.57, test acc:0.5099 ===
# train loss:1.4943012864608227
# train loss:1.6305148725445044
# train loss:1.5413941727910927
# === epoch:281, train acc:0.5666666666666667, test acc:0.5089 ===
# train loss:1.606217005636863
# train loss:1.6086867422050282
# train loss:1.737051064904504
# === epoch:282, train acc:0.5733333333333334, test acc:0.5134 ===
# train loss:1.486920671915595
# train loss:1.5539893186307199
# train loss:1.5359250132604905
# === epoch:283, train acc:0.5733333333333334, test acc:0.5149 ===
# train loss:1.579231389988416
# train loss:1.6615321981777855
# train loss:1.5088772585182186
# === epoch:284, train acc:0.58, test acc:0.5178 ===
# train loss:1.5246168589610785
# train loss:1.5720326418072217
# train loss:1.5824146586287275
# === epoch:285, train acc:0.5766666666666667, test acc:0.5189 ===
# train loss:1.4645963453901245
# train loss:1.447452435560108
# train loss:1.5242423984882623
# === epoch:286, train acc:0.5766666666666667, test acc:0.518 ===
# train loss:1.4928259886434816
# train loss:1.5256659623101143
# train loss:1.5186724018236761
# === epoch:287, train acc:0.58, test acc:0.5225 ===
# train loss:1.4871065293819348
# train loss:1.5917023101908188
# train loss:1.5441134022456362
# === epoch:288, train acc:0.5733333333333334, test acc:0.5265 ===
# train loss:1.4495134806601957
# train loss:1.5763201204449786
# train loss:1.509863916853003
# === epoch:289, train acc:0.5733333333333334, test acc:0.5276 ===
# train loss:1.513048198314743
# train loss:1.5430299559797387
# train loss:1.508729099314846
# === epoch:290, train acc:0.5766666666666667, test acc:0.5289 ===
# train loss:1.4738719023054816
# train loss:1.6879873860620722
# train loss:1.600419025691385
# === epoch:291, train acc:0.5833333333333334, test acc:0.531 ===
# train loss:1.444906155492464
# train loss:1.5080580725493797
# train loss:1.5069418117975453
# === epoch:292, train acc:0.5833333333333334, test acc:0.5291 ===
# train loss:1.5326626293598629
# train loss:1.3949170835695481
# train loss:1.481561091552321
# === epoch:293, train acc:0.5866666666666667, test acc:0.5285 ===
# train loss:1.6105226078152821
# train loss:1.33702783847163
# train loss:1.3537603262075881
# === epoch:294, train acc:0.5866666666666667, test acc:0.5289 ===
# train loss:1.4346264972134595
# train loss:1.5149604483750267
# train loss:1.4803921483788764
# === epoch:295, train acc:0.5866666666666667, test acc:0.5304 ===
# train loss:1.4671008817047817
# train loss:1.461476442699542
# train loss:1.6292002233337968
# === epoch:296, train acc:0.59, test acc:0.5316 ===
# train loss:1.398268747583252
# train loss:1.4114725134043722
# train loss:1.588425794345068
# === epoch:297, train acc:0.5966666666666667, test acc:0.5321 ===
# train loss:1.6128042623463714
# train loss:1.4158593083872595
# train loss:1.4351246998201943
# === epoch:298, train acc:0.59, test acc:0.5331 ===
# train loss:1.5089608999485349
# train loss:1.4749435934534245
# train loss:1.390371527564149
# === epoch:299, train acc:0.5966666666666667, test acc:0.538 ===
# train loss:1.3438717640657973
# train loss:1.496965505546267
# train loss:1.4412639919943182
# === epoch:300, train acc:0.5966666666666667, test acc:0.5402 ===
# train loss:1.3862492549872991
# train loss:1.4620170741004974
# train loss:1.475977478566855
# === epoch:301, train acc:0.5966666666666667, test acc:0.5431 ===
# train loss:1.4752131049126032
# train loss:1.292403818593046
# =============== Final Test Accuracy ===============
# test acc:0.5439

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)

x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.74 | lr:0.005053020491062965, weight decay:9.224572406187568e-07
# val acc:0.11 | lr:3.006980604711738e-06, weight decay:3.393263239684035e-05
# val acc:0.05 | lr:2.7797628319010903e-05, weight decay:2.428276708363992e-07
# val acc:0.12 | lr:3.37353926130714e-05, weight decay:7.062061765213552e-08
# val acc:0.09 | lr:1.0501965523186562e-06, weight decay:2.3987526301487803e-05
# val acc:0.21 | lr:0.0022229612130213166, weight decay:4.077999699270335e-05
# val acc:0.07 | lr:0.0007595639227952621, weight decay:4.599855335554081e-07
# val acc:0.06 | lr:6.843373877555514e-06, weight decay:5.9869511860835905e-06
# val acc:0.32 | lr:0.0020873007985993805, weight decay:5.067639867078411e-07
# val acc:0.53 | lr:0.0036104243256323606, weight decay:3.6001393375429214e-07
# val acc:0.1 | lr:4.1070635503636695e-06, weight decay:9.953043513057653e-06
# val acc:0.1 | lr:4.2228661685336646e-05, weight decay:4.1514343792481204e-08
# val acc:0.05 | lr:2.0570798007184026e-05, weight decay:1.7060975561749284e-08
# val acc:0.09 | lr:0.00015482466409968924, weight decay:3.5932295836812373e-06
# val acc:0.41 | lr:0.00223276955218832, weight decay:5.870315416463607e-08
# val acc:0.61 | lr:0.004239623836682792, weight decay:4.9004227926814115e-05
# val acc:0.11 | lr:2.00224591387198e-06, weight decay:9.977023117537105e-06
# val acc:0.03 | lr:2.7118124248069143e-06, weight decay:6.78298015400753e-08
# val acc:0.11 | lr:0.00025579055322829297, weight decay:2.9162027008790123e-08
# val acc:0.05 | lr:2.069883267277054e-05, weight decay:3.3719280885958996e-05
# val acc:0.1 | lr:2.2118763314027624e-05, weight decay:1.4141103919580685e-05
# val acc:0.13 | lr:3.054775535437858e-05, weight decay:4.691022113915498e-07
# val acc:0.08 | lr:1.7181315462895857e-06, weight decay:2.124263133952556e-06
# val acc:0.05 | lr:4.9039598060738366e-05, weight decay:2.51368854398413e-05
# val acc:0.09 | lr:3.4367478960347285e-06, weight decay:1.3875435754863915e-07
# val acc:0.12 | lr:0.00026569247546329096, weight decay:1.3127794237128356e-06
# val acc:0.29 | lr:0.0015304315195691916, weight decay:1.9329021951234494e-08
# val acc:0.42 | lr:0.0019517620740430095, weight decay:9.353228245289737e-05
# val acc:0.13 | lr:0.00015427744638954347, weight decay:1.2252987029647462e-05
# val acc:0.09 | lr:8.229956035589377e-06, weight decay:3.6306215699754405e-08
# val acc:0.06 | lr:0.00016768183598646146, weight decay:2.2795841422024146e-06
# val acc:0.06 | lr:6.0872008633473415e-05, weight decay:8.307896115140481e-06
# val acc:0.1 | lr:1.4482129298006456e-05, weight decay:3.5603996428096157e-06
# val acc:0.13 | lr:3.287244285341662e-06, weight decay:7.907820862793326e-06
# val acc:0.29 | lr:0.0011297999680553665, weight decay:1.1415111384528752e-08
# val acc:0.07 | lr:0.0008381549041321079, weight decay:5.270469606267433e-06
# val acc:0.09 | lr:5.309316635094143e-06, weight decay:3.335908107428771e-08
# val acc:0.8 | lr:0.006572897046043383, weight decay:9.698161057557053e-07
# val acc:0.06 | lr:1.0803084848482206e-06, weight decay:5.461231339362058e-06
# val acc:0.11 | lr:0.0001822379809757471, weight decay:1.4645637864456368e-05
# val acc:0.73 | lr:0.004448979464673091, weight decay:7.639976514888084e-05
# val acc:0.82 | lr:0.007975907233436932, weight decay:4.632494369278515e-07
# val acc:0.24 | lr:0.0004775138505198604, weight decay:3.036780995850515e-07
# val acc:0.72 | lr:0.0038949382888103508, weight decay:2.8934215737239124e-06
# val acc:0.21 | lr:7.286827840949306e-05, weight decay:1.3451639464447422e-05
# val acc:0.09 | lr:0.00041597654315060216, weight decay:5.652898034068625e-07
# val acc:0.19 | lr:0.0001251896469377963, weight decay:4.18754470216606e-08
# val acc:0.08 | lr:0.00010608429364877799, weight decay:6.32646429025116e-06
# val acc:0.06 | lr:5.984795807215995e-06, weight decay:2.2119243044476965e-08
# val acc:0.33 | lr:0.0010342747908061876, weight decay:7.335353368612115e-05
# val acc:0.26 | lr:0.0006545408258984137, weight decay:2.1129786652230033e-08
# val acc:0.05 | lr:1.2654030201975995e-05, weight decay:1.199517831814484e-08
# val acc:0.81 | lr:0.008484940695481146, weight decay:4.775370013009749e-07
# val acc:0.79 | lr:0.006726831869869547, weight decay:2.4256975874592385e-07
# val acc:0.75 | lr:0.008028875311119, weight decay:4.926468779047215e-06
# val acc:0.07 | lr:3.625426259404653e-05, weight decay:7.224911623204076e-05
# val acc:0.08 | lr:1.151583965263246e-06, weight decay:1.4129059490113144e-06
# val acc:0.12 | lr:7.978408990832081e-05, weight decay:9.93452861630461e-07
# val acc:0.09 | lr:1.460112128658458e-06, weight decay:3.594850823617358e-08
# val acc:0.14 | lr:9.047392694167594e-05, weight decay:1.8583827914200082e-05
# val acc:0.08 | lr:4.833294774040806e-06, weight decay:8.635916136147871e-06
# val acc:0.13 | lr:5.395269588578591e-06, weight decay:2.6541376416317977e-08
# val acc:0.72 | lr:0.005921444510201458, weight decay:3.3417270925212375e-08
# val acc:0.03 | lr:7.310662429414394e-06, weight decay:3.86316142323585e-06
# val acc:0.04 | lr:1.5861037823332404e-06, weight decay:1.25532180061321e-07
# val acc:0.07 | lr:0.00010178773670502483, weight decay:2.960320592419247e-07
# val acc:0.09 | lr:4.235580670545738e-06, weight decay:2.4520466959278015e-08
# val acc:0.5 | lr:0.004034031361397153, weight decay:1.7291632800464685e-05
# val acc:0.1 | lr:9.559243651694055e-06, weight decay:8.709405684048822e-08
# val acc:0.08 | lr:5.115065350965538e-05, weight decay:3.234599730856986e-08
# val acc:0.08 | lr:1.6952251472682908e-06, weight decay:1.2013529618100921e-06
# val acc:0.07 | lr:0.0001248554881504668, weight decay:5.479036066730825e-07
# val acc:0.66 | lr:0.004503359382417267, weight decay:1.7483139712792947e-07
# val acc:0.18 | lr:1.9980847573367333e-06, weight decay:1.2768021660079136e-08
# val acc:0.1 | lr:1.3375183428379238e-05, weight decay:3.751285792271842e-07
# val acc:0.09 | lr:3.029071249199257e-05, weight decay:6.640283326187923e-08
# val acc:0.41 | lr:0.0012981190884686173, weight decay:5.0141876412039864e-05
# val acc:0.31 | lr:0.0019070254448917542, weight decay:1.5627013530010426e-05
# val acc:0.12 | lr:1.8396742562249233e-05, weight decay:1.4013218180562269e-06
# val acc:0.16 | lr:2.2366412564427217e-05, weight decay:5.119407730122432e-06
# val acc:0.16 | lr:0.00018177561120216076, weight decay:6.642487554207398e-05
# val acc:0.09 | lr:5.682687347305316e-05, weight decay:2.938878099243902e-06
# val acc:0.07 | lr:0.00015561471599323553, weight decay:1.5446199838803783e-07
# val acc:0.2 | lr:0.00041016230105082543, weight decay:5.981649203646513e-07
# val acc:0.1 | lr:5.438986683380378e-05, weight decay:6.941896472893451e-06
# val acc:0.06 | lr:1.5304966938872464e-05, weight decay:1.5622653478164885e-07
# val acc:0.09 | lr:0.00011212118832981208, weight decay:3.376922822214783e-05
# val acc:0.07 | lr:1.0719401590166713e-05, weight decay:1.6334546961967416e-07
# val acc:0.17 | lr:0.0006141221110367924, weight decay:3.823014923688293e-07
# val acc:0.1 | lr:8.416916291854822e-06, weight decay:1.686915007138158e-05
# val acc:0.74 | lr:0.0057786450422123445, weight decay:6.317591151884002e-08
# val acc:0.09 | lr:0.00043702724330524844, weight decay:1.7571799590282528e-07
# val acc:0.23 | lr:0.0013826718548578098, weight decay:7.692493505128009e-08
# val acc:0.1 | lr:0.0008172812415790186, weight decay:1.3471910384995153e-06
# val acc:0.08 | lr:0.00016580897852731325, weight decay:1.548108491765824e-07
# val acc:0.07 | lr:3.959147675599114e-05, weight decay:3.6360697248293487e-06
# val acc:0.14 | lr:0.0004013252821467004, weight decay:2.9178579953984993e-08
# val acc:0.11 | lr:1.756922555917451e-05, weight decay:5.326490897234869e-07
# val acc:0.35 | lr:0.002732641129155927, weight decay:2.321491430314692e-05
# val acc:0.79 | lr:0.006204251036307237, weight decay:2.464138325636379e-07
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.82) | lr:0.007975907233436932, weight decay:4.632494369278515e-07
# Best-2(val acc:0.81) | lr:0.008484940695481146, weight decay:4.775370013009749e-07
# Best-3(val acc:0.8) | lr:0.006572897046043383, weight decay:9.698161057557053e-07
# Best-4(val acc:0.79) | lr:0.006726831869869547, weight decay:2.4256975874592385e-07
# Best-5(val acc:0.79) | lr:0.006204251036307237, weight decay:2.464138325636379e-07
# Best-6(val acc:0.75) | lr:0.008028875311119, weight decay:4.926468779047215e-06
# Best-7(val acc:0.74) | lr:0.005053020491062965, weight decay:9.224572406187568e-07
# Best-8(val acc:0.74) | lr:0.0057786450422123445, weight decay:6.317591151884002e-08
# Best-9(val acc:0.73) | lr:0.004448979464673091, weight decay:7.639976514888084e-05
# Best-10(val acc:0.72) | lr:0.0038949382888103508, weight decay:2.8934215737239124e-06
# Best-11(val acc:0.72) | lr:0.005921444510201458, weight decay:3.3417270925212375e-08
# Best-12(val acc:0.66) | lr:0.004503359382417267, weight decay:1.7483139712792947e-07
# Best-13(val acc:0.61) | lr:0.004239623836682792, weight decay:4.9004227926814115e-05
# Best-14(val acc:0.53) | lr:0.0036104243256323606, weight decay:3.6001393375429214e-07
# Best-15(val acc:0.5) | lr:0.004034031361397153, weight decay:1.7291632800464685e-05
# Best-16(val acc:0.42) | lr:0.0019517620740430095, weight decay:9.353228245289737e-05
# Best-17(val acc:0.41) | lr:0.00223276955218832, weight decay:5.870315416463607e-08
# Best-18(val acc:0.41) | lr:0.0012981190884686173, weight decay:5.0141876412039864e-05
# Best-19(val acc:0.35) | lr:0.002732641129155927, weight decay:2.321491430314692e-05
# Best-20(val acc:0.33) | lr:0.0010342747908061876, weight decay:7.335353368612115e-05
